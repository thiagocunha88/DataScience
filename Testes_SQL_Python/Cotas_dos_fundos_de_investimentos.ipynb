# %%
import pandas as pd
ano = str(input('Digite o ano: '))
mes = int(input('Digite o mês: '))
mes_formatado = {1: '01', 
                 2: '02', 
                 3: '03', 
                 4: '04', 
                 5: '05', 
                 6: '06', 
                 7: '07', 
                 8: '08', 
                 9: '09',
                 10: '10', 
                 11: '11', 
                 12: '12'}

fundos = pd.read_csv(
    f'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_{ano}{mes_formatado[mes]}.csv', 
    sep=';')

fundos = fundos[(fundos['CNPJ_FUNDO'] == '03.187.084/0001-02') | 
                (fundos['CNPJ_FUNDO'] == '16.916.063/0001-22') | 
                (fundos['CNPJ_FUNDO'] == '07.214.377/0001-92') | 
                (fundos['CNPJ_FUNDO'] == '04.288.966/0001-27') | 
                (fundos['CNPJ_FUNDO'] == '02.506.721/0001-01')]

fundos.to_excel(f'C:/Users/thiago.cunha/Documents/Python/Cotas fundos/cotas_fundos.xlsx', index=False)
print('Download completo!')
# Out:
# Digite o ano: 2022
# Digite o mês: 2
# Download completo!

# %%
import pandas as pd
from datetime import datetime as dt

# %%
# Out:
# 2022

# %%
# %%time
ano = int(input('Digite o ano: '))
fundos = pd.DataFrame()

mes_formatado = {1: '01', 
                 2: '02', 
                 3: '03', 
                 4: '04', 
                 5: '05', 
                 6: '06', 
                 7: '07', 
                 8: '08', 
                 9: '09',
                 10: '10', 
                 11: '11', 
                 12: '12'}

while 2018 > ano or ano > dt.today().year:
    print('O ano precisa ser menor ou igual ao atual.')
    ano = int(input('Digite o ano: '))
    
if ano == dt.today().year:
    for mes in range(1, dt.today().month + 1):
        fundo = pd.read_csv(
            f'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_{ano}{mes_formatado[mes]}.csv',
            sep=';')
        fundos = pd.concat([fundos, fundo])
else:
    for mes in range(1, 13):
        fundo = pd.read_csv(
            f'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_{ano}{mes_formatado[mes]}.csv',
            sep=';')
        fundos = pd.concat([fundos, fundo])
# Out:
# Digite o ano: 2021

# %%
fundos
# Out:
#        TP_FUNDO          CNPJ_FUNDO   DT_COMPTC     VL_TOTAL   VL_QUOTA  \
# 0            FI  00.017.024/0001-53  2022-01-03   1075476.00  28.110273
# 1            FI  00.017.024/0001-53  2022-01-04   1075873.10  28.118682
# 2            FI  00.017.024/0001-53  2022-01-05   1076280.19  28.127768
# 3            FI  00.017.024/0001-53  2022-01-06   1076680.92  28.137115
# 4            FI  00.017.024/0001-53  2022-01-07   1073899.79  28.146295
# ...         ...                 ...         ...          ...        ...
# 297557       FI  97.929.213/0001-34  2022-02-11  71119813.47   9.357819
# 297558       FI  97.929.213/0001-34  2022-02-14  71233959.43   9.372789
# 297559       FI  97.929.213/0001-34  2022-02-15  71449032.70   9.401097
# 297560       FI  97.929.213/0001-34  2022-02-16  71415907.14   9.399582
# 297561       FI  97.929.213/0001-34  2022-02-17  71232716.78   9.375425
#
#         VL_PATRIM_LIQ  CAPTC_DIA  RESG_DIA  NR_COTST
# ...

# %%
ano = int(input('Digite o ano: '))
while 2018 > ano or ano > dt.today().year:
    print('O ano precisa ser menor ou igual ao atual.')
    ano = int(input('Digite o ano: '))
# Out:
# Digite o ano: 2016
# O ano precisa ser menor ou igual ao atual.
# Digite o ano: 0
# O ano precisa ser menor ou igual ao atual.
# Digite o ano: 2019

# %%
ano = str(input('Digite o ano: '))
mes_formatado = {1: '01', 
                 2: '02', 
                 3: '03', 
                 4: '04', 
                 5: '05', 
                 6: '06', 
                 7: '07', 
                 8: '08', 
                 9: '09',
                 10: '10', 
                 11: '11', 
                 12: '12'}



fundos = pd.read_csv(
    f'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_{ano}{mes_formatado[mes]}.csv', 
    sep=';')

fundos = fundos[(fundos['CNPJ_FUNDO'] == '03.187.084/0001-02') | 
                (fundos['CNPJ_FUNDO'] == '16.916.063/0001-22') | 
                (fundos['CNPJ_FUNDO'] == '07.214.377/0001-92') | 
                (fundos['CNPJ_FUNDO'] == '04.288.966/0001-27') | 
                (fundos['CNPJ_FUNDO'] == '02.506.721/0001-01')]

fundos.to_excel(f'C:/Users/thiago.cunha/Documents/Python/Cotas fundos/cotas_fundos.xlsx', index=False)
print('Download completo!')

fundos_2 = pd.crosstab(index=fundos_2022_01['DT_COMPTC'], 
                       columns=fundos_2022_01['CNPJ_FUNDO'], 
                       values=fundos_2022_01['VL_QUOTA'], 
                      aggfunc='sum')

# %%
fundos_2
# Out:
# CNPJ_FUNDO  02.506.721/0001-01  03.187.084/0001-02  04.288.966/0001-27  \
# DT_COMPTC
# 2022-02-01           13.660306            3.533720            3.831552
# 2022-02-02           13.664828            3.534653            3.832598
# 2022-02-03           13.669264            3.535594            3.833613
# 2022-02-04           13.674333            3.536703            3.834805
# 2022-02-07           13.679716            3.537827            3.836085
# 2022-02-08           13.685006            3.538972            3.837345
# 2022-02-09           13.690191            3.540121            3.838570
# 2022-02-10           13.695425            3.541558            3.839795
# 2022-02-11           13.700671            3.542687            3.841033
# 2022-02-14           13.705914            3.543763            3.842241
# 2022-02-15           13.711125            3.544859            3.843462
# 2022-02-16           13.716387            3.545966            3.844683
# ...

# %%
fundos_pct = fundos_2.pct_change(axis=0)*100

# %%
fundos_pct.plot(legend=False, figsize = (12,6))
# Out:
# <AxesSubplot:xlabel='DT_COMPTC'>

# %%
fundos_pct
# Out:
# CNPJ_FUNDO  02.506.721/0001-01  03.187.084/0001-02  04.288.966/0001-27  \
# DT_COMPTC
# 2022-02-01                 NaN                 NaN                 NaN
# 2022-02-02            0.033101            0.026403            0.027315
# 2022-02-03            0.032466            0.026622            0.026478
# 2022-02-04            0.037079            0.031367            0.031095
# 2022-02-07            0.039370            0.031781            0.033362
# 2022-02-08            0.038666            0.032364            0.032858
# 2022-02-09            0.037892            0.032467            0.031914
# 2022-02-10            0.038229            0.040592            0.031929
# 2022-02-11            0.038304            0.031879            0.032226
# 2022-02-14            0.038267            0.030372            0.031446
# 2022-02-15            0.038023            0.030928            0.031789
# 2022-02-16            0.038373            0.031228            0.031774
# ...

# %%
import pandas as pd
ano = str(input('Digite o ano: '))
mes = int(input('Digite o mês: '))
mes_formatado = {1: '01', 
                 2: '02', 
                 3: '03', 
                 4: '04', 
                 5: '05', 
                 6: '06', 
                 7: '07', 
                 8: '08', 
                 9: '09',
                 10: '10', 
                 11: '11', 
                 12: '12'}

fundos = pd.read_csv(
    f'http://dados.cvm.gov.br/dados/FI/DOC/INF_DIARIO/DADOS/inf_diario_fi_{ano}{mes_formatado[mes]}.csv', 
    sep=';')
# Out:
# Digite o ano: 2022
# Digite o mês: 1

# %%
fundos.TP_FUNDO.unique()
# Out:
# array(['FI', 'FAPI', 'FMP-FGTS', 'FMP-FGTS CL', 'FACFIF', 'FIF'],
#       dtype=object)
